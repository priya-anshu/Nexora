# %% [markdown]
# # EDA — Customer Churn
#
# Basic checks for class balance and tabular feature distributions before neural network training.

# %%
import pandas as pd

churn = pd.read_csv('../data/customer_churn.csv')
churn.head()

# %%
churn['Churn'].value_counts(normalize=True).rename('rate')
